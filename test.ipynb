# %%
from Lexer.lexer import Lexer
from Grammar import *



nonzero_digits = '|'.join(str(n) for n in range(1,10))
letters = '|'.join(chr(n) for n in range(ord('a'),ord('z')+1))
upper_letters= '|'.join(chr(n) for n in range(ord('A'),ord('Z')+1))
num1=f'({nonzero_digits})(0|{nonzero_digits})*.(0|{nonzero_digits})(0|{nonzero_digits})*'
num2=f'({nonzero_digits})(0|{nonzero_digits})*'
num3=f'0.(0|{nonzero_digits})(0|{nonzero_digits})*'
number = '|'.join(n for n in [num1,num2,num3,'0'])   
symbols="!|@|%|^|&|_|+|-|:|;|<|>|=|,|.|?|~|`|[|]|{|}|#|¿|¡|º|ª|¬|'"
string= f'"({symbols}|0| |{nonzero_digits}|{letters}|{upper_letters})*"'
constx='PI|E'
bool= 'true|false'

# lexer = Lexer([
#             ('for' , 'for'),
#             ('let','let'),
#             ('in','in'),
#             ('if','if'),
#             ('elif','elif'),
#             ('else','else'),
#             ('while','while'),
#             ('as','as'),
#             ('is','is'),
#             ('new','new'),
#             ('function','function'),
#             ('type','type'),
#             ('inherits','inherits'),
#             ('protocol','protocol'),
#             ('extends','extends'),
#             ('+','+'),
#             ('-','-'), 
#             ('*','\\*'), 
#             ('/','/'), 
#             ('%','%'), 
#             ('^','^'), 
#             ('**','\\\\**'), 
#             ('=','='), 
#             (':=',':='), 
#             ('==','=='), 
#             ('!=','!='), 
#             ('<','<'), 
#             ('>','>'), 
#             ('<=','<='), 
#             ('>=','>='), 
#             ('&','&'), 
#             ('|','\\|'), 
#             ('!','!'), 
#             ('||','\\\\||'),
#             ('.','.'), 
#             (',',','), 
#             (':',':'), 
#             ('@','@'), 
#             ('@@','@@'), 
#             ('=>','=>'), 
#             ('(','\\('), 
#             (')','\\)'), 
#             ('[','['), 
#             (']',']'), 
#             ('{','{'), 
#             ('}','}'), 
#             (';',';'),
#             ('str', string),
#             ('num',f'({number})'),
#             ('bool',f'({bool})'),
#             ('const',f'({const})'),
#             ('space', '  *'),
#             ('id', f'({letters})({letters}|0|{nonzero_digits}|{upper_letters})*'),
#             ('type_id',f'({upper_letters})({letters}|0|{nonzero_digits}|{upper_letters})*')
#         ], 'eof')

lexer = Lexer([
            (forx , 'for'),
            (letx,'let'),
            (inx,'in'),
            (ifx,'if'),
            (elifx,'elif'),
            (elsex,'else'),
            (whilex,'while'),
            (asx,'as'),
            (isx,'is'),
            (newx,'new'),
            (function,'function'),
            (typex,'type'),
            (inherits,'inherits'),
            (protocol,'protocol'),
            (extends,'extends'),
            (plus,'+'),
            (minus,'-'),  
            (div,'/'), 
            (mod,'%'), 
            (powx,'^'), 
            (starstar,'\*\*'), 
            (star,'\*'),
            (eq,'='), 
            (coloneq,':='), 
            (eqeq,'=='), 
            (noteq,'!='), 
            (less,'<'), 
            (greater,'>'), 
            (leq,'<='), 
            (geq,'>='), 
            (orxorx,'\|\|'),
            (andx,'&'), 
            (orx,'\|'), 
            (notx,'!'), 
            (dot,'.'), 
            (comma,','), 
            (colon,':'), 
            (at,'@'), 
            (atat,'@@'), 
            (arrow,'=>'), 
            (opar,'\('), 
            (cpar,'\)'), 
            (obrack,'['), 
            (cbrack,']'), 
            (obrace,'{'), 
            (cbrace,'}'), 
            (semi,';'),
            (strx, string),
            (num,f'({number})'),
            (boolx,f'({bool})'),
            (const,f'({constx})'),
            ('space', '  *'),
            (idx, f'({letters})({letters}|0|{nonzero_digits}|{upper_letters})*'),
            (type_idx,f'({upper_letters})({letters}|0|{nonzero_digits}|{upper_letters})*')
        ], 'eof')

text = '''
function tan(x: Number): Number => sin(x) / cos(x);
function cot(x) => 1 / tan(x);
function operate(x, y) {
    print(x + y);
    print(x - y);
    print(x * y);
    print(x / y);
}
function fib(n) => if (n == 0 | n == 1) 1 else fib(n-1) + fib(n-2);
function fact(x) => let f = 1 in for (i in range(1, x+1)) f := f * i;
function gcd(a, b) => while (a > 0)
        let m = a % b in {
            b := a;
            a := m;
        };
protocol Hashable {
    hash(): Number;
}
protocol Equatable extends Hashable {
    equals(other: Object): Boolean;
}
protocol Iterable {
    next() : Boolean;
    current() : Object;
}
type Range(min:Number, max:Number) {
    min = min;
    max = max;
    current = min - 1;

    next(): Boolean => (self.current := self.current + 1) < self.max;
    current(): Number => self.current;
}
type Point(x,y) {
    x = x;
    y = y;

    getX() => self.x;
    getY() => self.y;

    setX(x) => self.x := x;
    setY(y) => self.y := y;
}
type PolarPoint(phi, rho) inherits Point(rho * sin(phi), rho * cos(phi)) {
    rho() => sqrt(self.getX() ^ 2 + self.getY() ^ 2);
}
type Knight inherits Person {
    name() => "Sir" @@ base();
}
type Person(firstname, lastname) {
    firstname = firstname;
    lastname = lastname;

    name() => self.firstname @@ self.lastname;
    hash() : Number {
        5;
    }
}
type Superman {
}
type Bird {
}
type Plane {
}
type A {
    hello() => print("A");
}

type B inherits A {
    hello() => print("B");
}

type C inherits A {
    hello() => print("C");
}

{
    42;
    print(42);
    print((((1 + 2) ^ 3) * 4) / 5);
    print("Hello World");

    print("The meaning of life is " @ 42);
    print(sin(2 * PI) ^ 2 + cos(3 * PI / log(4, 64)));
    {
        print(42);
        print(sin(PI/2));
        print("Hello World");
    }


    print(tan(PI) * 2 + cot(PI) * 2);

    let msg = "Hello World" in print(msg);
    let number = 42, text = "The meaning of life is" in
        print(text @ number);
    let number = 42 in
        let text = "The meaning of life is" in
            print(text @ number);
    let number = 42 in (
        let text = "The meaning of life is" in (
                print(text @ number)
            )
        );
    let a = 6, b = a * 7 in print(b);
    let a = 6 in
        let b = a * 7 in
            print(b);
    let a = 5, b = 10, c = 20 in {
        print(a+b);
        print(b*c);
        print(c/a);
    };
    let a = (let b = 6 in b * 7) in print(a);
    print(let b = 6 in b * 7);
    let a = 20 in {
        let a = 42 in print(a);
        print(a);
    };
    let a = 7, a = 7 * 6 in print(a);
    let a = 7 in
        let a = 7 * 6 in
            print(a);
    let a = 0 in {
        print(a);
        a := 1;
        print(a);
    };
    let a = 0 in
        let b = a := 1 in {
            print(a);
            print(b);
        };
    let a = 42 in if (a % 2 == 0) print("Even") else print("odd");
    let a = 42 in print(if (a % 2 == 0) "even" else "odd");
    let a = 42 in
        if (a % 2 == 0) {
            print(a);
            print("Even");
        }
        else print("Odd");

    let a = 10 in while (a >= 0) {
        print(a);
        a := a - 1;
    }

    for (x in range(0, 10)) print(x);
    let iterable = range(0, 10) in
        while (iterable.next())
            let x = iterable.current() in
                print(x);

        print("x: " @ pt.getX() @ "; y: " @ pt.getY());
    let pt = new Point(3,4) in
        print("x: " @ pt.getX() @ "; y: " @ pt.getY());
    let pt = new PolarPoint(3,4) in
        print("rho: " @ pt.rho());

    let p = new Knight("Phil", "Collins") in
        print(p.name());
    let p: Person = new Knight("Phil", "Collins") in print(p.name());
    let x: Number = 42 in print(x);

    let x = new Superman() in
        print(
            if (x is Bird) "It's bird!"
            elif (x is Plane) "It's a plane!"
            else "No, it's Superman!"
        );
    let x = 42 in print(x);
    '''
tokens1 = lexer(text)
token=[]
for tk in tokens1:
    if tk.token_type == 'space':
        continue
    else:
        token.append(tk)
        print(tk)
# Out:
# <>:96: SyntaxWarning: invalid escape sequence '\*'
# <>:97: SyntaxWarning: invalid escape sequence '\*'
# <>:106: SyntaxWarning: invalid escape sequence '\|'
# <>:108: SyntaxWarning: invalid escape sequence '\|'
# <>:116: SyntaxWarning: invalid escape sequence '\('
# <>:117: SyntaxWarning: invalid escape sequence '\)'
# <>:96: SyntaxWarning: invalid escape sequence '\*'
# <>:97: SyntaxWarning: invalid escape sequence '\*'
# <>:106: SyntaxWarning: invalid escape sequence '\|'
# <>:108: SyntaxWarning: invalid escape sequence '\|'
# <>:116: SyntaxWarning: invalid escape sequence '\('
# <>:117: SyntaxWarning: invalid escape sequence '\)'
# /tmp/ipykernel_32106/3877980438.py:96: SyntaxWarning: invalid escape sequence '\*'
#   (starstar,'\*\*'),
# /tmp/ipykernel_32106/3877980438.py:97: SyntaxWarning: invalid escape sequence '\*'
#   (star,'\*'),
# /tmp/ipykernel_32106/3877980438.py:106: SyntaxWarning: invalid escape sequence '\|'
#   (orxorx,'\|\|'),
# /tmp/ipykernel_32106/3877980438.py:108: SyntaxWarning: invalid escape sequence '\|'
#   (orx,'\|'),
# /tmp/ipykernel_32106/3877980438.py:116: SyntaxWarning: invalid escape sequence '\('
#   (opar,'\('),
# /tmp/ipykernel_32106/3877980438.py:117: SyntaxWarning: invalid escape sequence '\)'
#   (cpar,'\)'),
# function: function (2,10)
# id: tan (2,14)
# (: ( (2,15)
# id: x (2,16)
# :: : (2,17)
# type_id: Number (2,24)
# ): ) (2,25)
# :: : (2,26)
# type_id: Number (2,33)
# =>: => (2,36)
# id: sin (2,40)
# (: ( (2,41)
# id: x (2,42)
# ): ) (2,43)
# /: / (2,45)
# id: cos (2,49)
# (: ( (2,50)
# id: x (2,51)
# ): ) (2,52)
# ;: ; (3,2)
# function: function (4,10)
# id: cot (4,14)
# (: ( (4,15)
# id: x (4,16)
# ): ) (4,17)
# =>: => (4,20)
# num: 1 (4,22)
# /: / (4,24)
# id: tan (4,28)
# (: ( (4,29)
# id: x (4,30)
# ): ) (4,31)
# ;: ; (5,2)
# function: function (6,10)
# id: operate (6,18)
# (: ( (6,19)
# id: x (6,20)
# ,: , (6,21)
# id: y (6,23)
# ): ) (6,24)
# {: { (7,2)
# id: print (8,11)
# (: ( (8,12)
# id: x (8,13)
# +: + (8,15)
# id: y (8,17)
# ): ) (8,18)
# ;: ; (9,2)
# id: print (10,11)
# (: ( (10,12)
# id: x (10,13)
# -: - (10,15)
# id: y (10,17)
# ): ) (10,18)
# ;: ; (11,2)
# id: print (12,11)
# (: ( (12,12)
# id: x (12,13)
# *: * (12,15)
# id: y (12,17)
# ): ) (12,18)
# ;: ; (13,2)
# id: print (14,11)
# (: ( (14,12)
# id: x (14,13)
# /: / (14,15)
# id: y (14,17)
# ): ) (14,18)
# ;: ; (15,2)
# }: } (17,2)
# function: function (18,10)
# id: fib (18,14)
# (: ( (18,15)
# id: n (18,16)
# ): ) (18,17)
# =>: => (18,20)
# if: if (18,23)
# (: ( (18,25)
# id: n (18,26)
# ==: == (18,29)
# num: 0 (18,31)
# id: or (18,34)
# id: n (18,36)
# ==: == (18,39)
# num: 1 (18,41)
# ): ) (18,42)
# num: 1 (18,44)
# else: else (18,49)
# id: fib (18,53)
# (: ( (18,54)
# id: n (18,55)
# -: - (18,56)
# num: 1 (18,57)
# ): ) (18,58)
# +: + (18,60)
# id: fib (18,64)
# (: ( (18,65)
# id: n (18,66)
# -: - (18,67)
# num: 2 (18,68)
# ): ) (18,69)
# ;: ; (19,2)
# function: function (20,10)
# id: fact (20,15)
# (: ( (20,16)
# id: x (20,17)
# ): ) (20,18)
# =>: => (20,21)
# let: let (20,25)
# id: f (20,27)
# =: = (20,29)
# num: 1 (20,31)
# in: in (20,34)
# for: for (20,38)
# (: ( (20,40)
# id: i (20,41)
# in: in (20,44)
# id: range (20,50)
# (: ( (20,51)
# num: 1 (20,52)
# ,: , (20,53)
# id: x (20,55)
# +: + (20,56)
# num: 1 (20,57)
# ): ) (20,58)
# ): ) (20,59)
# id: f (20,61)
# :=: := (20,64)
# id: f (20,66)
# *: * (20,68)
# id: i (20,70)
# ;: ; (21,2)
# function: function (22,10)
# id: gcd (22,14)
# (: ( (22,15)
# id: a (22,16)
# ,: , (22,17)
# id: b (22,19)
# ): ) (22,20)
# =>: => (22,23)
# while: while (22,29)
# (: ( (22,31)
# id: a (22,32)
# >: > (22,34)
# num: 0 (22,36)
# ): ) (23,2)
# let: let (24,13)
# id: m (24,15)
# =: = (24,17)
# id: a (24,19)
# %: % (24,21)
# id: b (24,23)
# in: in (24,26)
# {: { (25,2)
# id: b (26,15)
# :=: := (26,18)
# id: a (26,20)
# ;: ; (27,2)
# id: a (28,15)
# :=: := (28,18)
# id: m (28,20)
# ;: ; (29,2)
# }: } (30,11)
# ;: ; (31,2)
# protocol: protocol (32,10)
# type_id: Hashable (32,19)
# {: { (33,2)
# id: hash (34,10)
# (: ( (34,11)
# ): ) (34,12)
# :: : (34,13)
# type_id: Number (34,20)
# ;: ; (35,2)
# }: } (37,2)
# protocol: protocol (38,10)
# type_id: Equatable (38,20)
# extends: extends (38,28)
# type_id: Hashable (38,37)
# {: { (39,2)
# id: equals (40,12)
# (: ( (40,13)
# id: other (40,18)
# :: : (40,19)
# type_id: Object (40,26)
# ): ) (40,27)
# :: : (40,28)
# type_id: Boolean (40,36)
# ;: ; (41,2)
# }: } (43,2)
# protocol: protocol (44,10)
# type_id: Iterable (44,19)
# {: { (45,2)
# id: next (46,10)
# (: ( (46,11)
# ): ) (46,12)
# :: : (46,14)
# type_id: Boolean (46,22)
# ;: ; (47,2)
# id: current (48,13)
# (: ( (48,14)
# ): ) (48,15)
# :: : (48,17)
# type_id: Object (48,24)
# ;: ; (49,2)
# }: } (51,2)
# type: type (52,6)
# type_id: Range (52,12)
# (: ( (52,13)
# id: min (52,16)
# :: : (52,17)
# type_id: Number (52,23)
# ,: , (52,24)
# id: max (52,28)
# :: : (52,29)
# type_id: Number (52,35)
# ): ) (52,36)
# {: { (53,2)
# id: min (54,9)
# =: = (54,11)
# id: min (54,15)
# ;: ; (55,2)
# id: max (56,9)
# =: = (56,11)
# id: max (56,15)
# ;: ; (57,2)
# id: current (58,13)
# =: = (58,15)
# id: min (58,19)
# -: - (58,21)
# num: 1 (58,23)
# ;: ; (59,2)
# id: next (61,11)
# (: ( (61,12)
# ): ) (61,13)
# :: : (61,14)
# type_id: Boolean (61,22)
# =>: => (61,25)
# (: ( (61,27)
# id: self (61,31)
# .: . (61,32)
# id: current (61,39)
# :=: := (61,42)
# id: self (61,47)
# .: . (61,48)
# id: current (61,55)
# +: + (61,57)
# num: 1 (61,59)
# ): ) (61,60)
# <: < (61,62)
# id: self (61,67)
# .: . (61,68)
# id: max (61,71)
# ;: ; (62,2)
# id: current (63,13)
# (: ( (63,14)
# ): ) (63,15)
# :: : (63,16)
# type_id: Number (63,23)
# =>: => (63,26)
# id: self (63,31)
# .: . (63,32)
# id: current (63,39)
# ;: ; (64,2)
# }: } (66,2)
# type: type (67,6)
# type_id: Point (67,12)
# (: ( (67,13)
# id: x (67,14)
# ,: , (67,15)
# id: y (67,16)
# ): ) (67,17)
# {: { (68,2)
# id: x (69,7)
# =: = (69,9)
# id: x (69,11)
# ;: ; (70,2)
# id: y (71,7)
# =: = (71,9)
# id: y (71,11)
# ;: ; (72,2)
# id: getX (74,11)
# (: ( (74,12)
# ): ) (74,13)
# =>: => (74,16)
# id: self (74,21)
# .: . (74,22)
# id: x (74,23)
# ;: ; (75,2)
# id: getY (76,10)
# (: ( (76,11)
# ): ) (76,12)
# =>: => (76,15)
# id: self (76,20)
# .: . (76,21)
# id: y (76,22)
# ;: ; (77,2)
# id: setX (79,11)
# (: ( (79,12)
# id: x (79,13)
# ): ) (79,14)
# =>: => (79,17)
# id: self (79,22)
# .: . (79,23)
# id: x (79,24)
# :=: := (79,27)
# id: x (79,29)
# ;: ; (80,2)
# id: setY (81,10)
# (: ( (81,11)
# id: y (81,12)
# ): ) (81,13)
# =>: => (81,16)
# id: self (81,21)
# .: . (81,22)
# id: y (81,23)
# :=: := (81,26)
# id: y (81,28)
# ;: ; (82,2)
# }: } (84,2)
# type: type (85,6)
# type_id: PolarPoint (85,17)
# (: ( (85,18)
# id: phi (85,21)
# ,: , (85,22)
# id: rho (85,26)
# ): ) (85,27)
# inherits: inherits (85,36)
# type_id: Point (85,42)
# (: ( (85,43)
# id: rho (85,46)
# *: * (85,48)
# id: sin (85,52)
# (: ( (85,53)
# id: phi (85,56)
# ): ) (85,57)
# ,: , (85,58)
# id: rho (85,62)
# *: * (85,64)
# id: cos (85,68)
# (: ( (85,69)
# id: phi (85,72)
# ): ) (85,73)
# ): ) (85,74)
# {: { (86,2)
# id: rho (87,9)
# (: ( (87,10)
# ): ) (87,11)
# =>: => (87,14)
# id: sqrt (87,19)
# (: ( (87,20)
# id: self (87,24)
# .: . (87,25)
# id: getX (87,29)
# (: ( (87,30)
# ): ) (87,31)
# ^: ^ (87,33)
# num: 2 (87,35)
# +: + (87,37)
# id: self (87,42)
# .: . (87,43)
# id: getY (87,47)
# (: ( (87,48)
# ): ) (87,49)
# ^: ^ (87,51)
# num: 2 (87,53)
# ): ) (87,54)
# ;: ; (88,2)
# }: } (90,2)
# type: type (91,6)
# type_id: Knight (91,13)
# inherits: inherits (91,22)
# type_id: Person (91,29)
# {: { (92,2)
# id: name (93,10)
# (: ( (93,11)
# ): ) (93,12)
# =>: => (93,15)
# str: "Sir" (93,21)
# @@: @@ (93,24)
# id: base (93,29)
# (: ( (93,30)
# ): ) (93,31)
# ;: ; (94,2)
# }: } (96,2)
# type: type (97,6)
# type_id: Person (97,13)
# (: ( (97,14)
# id: firstname (97,23)
# ,: , (97,24)
# id: lastname (97,33)
# ): ) (97,34)
# {: { (98,2)
# id: firstname (99,15)
# =: = (99,17)
# id: firstname (99,27)
# ;: ; (100,2)
# id: lastname (101,14)
# =: = (101,16)
# id: lastname (101,25)
# ;: ; (102,2)
# id: name (104,11)
# (: ( (104,12)
# ): ) (104,13)
# =>: => (104,16)
# id: self (104,21)
# .: . (104,22)
# id: firstname (104,31)
# @@: @@ (104,34)
# id: self (104,39)
# .: . (104,40)
# id: lastname (104,48)
# ;: ; (105,2)
# id: hash (106,10)
# (: ( (106,11)
# ): ) (106,12)
# :: : (106,14)
# type_id: Number (106,21)
# {: { (107,2)
# num: 5 (108,11)
# ;: ; (109,2)
# }: } (111,2)
# }: } (113,2)
# type: type (114,6)
# type_id: Superman (114,15)
# {: { (115,2)
# }: } (117,2)
# type: type (118,6)
# type_id: Bird (118,11)
# {: { (119,2)
# }: } (121,2)
# type: type (122,6)
# type_id: Plane (122,12)
# {: { (123,2)
# }: } (125,2)
# type: type (126,6)
# type_id: A (126,8)
# {: { (127,2)
# id: hello (128,11)
# (: ( (128,12)
# ): ) (128,13)
# =>: => (128,16)
# id: print (128,22)
# (: ( (128,23)
# str: "A" (128,26)
# ): ) (128,27)
# ;: ; (129,2)
# }: } (131,2)
# type: type (133,7)
# type_id: B (133,9)
# inherits: inherits (133,18)
# type_id: A (133,20)
# {: { (134,2)
# id: hello (135,11)
# (: ( (135,12)
# ): ) (135,13)
# =>: => (135,16)
# id: print (135,22)
# (: ( (135,23)
# str: "B" (135,26)
# ): ) (135,27)
# ;: ; (136,2)
# }: } (138,2)
# type: type (140,7)
# type_id: C (140,9)
# inherits: inherits (140,18)
# type_id: A (140,20)
# {: { (141,2)
# id: hello (142,11)
# (: ( (142,12)
# ): ) (142,13)
# =>: => (142,16)
# id: print (142,22)
# (: ( (142,23)
# str: "C" (142,26)
# ): ) (142,27)
# ;: ; (143,2)
# }: } (145,2)
# {: { (148,2)
# num: 42 (149,8)
# ;: ; (150,2)
# id: print (151,11)
# (: ( (151,12)
# num: 42 (151,14)
# ): ) (151,15)
# ;: ; (152,2)
# id: print (153,11)
# (: ( (153,12)
# (: ( (153,13)
# (: ( (153,14)
# (: ( (153,15)
# num: 1 (153,16)
# +: + (153,18)
# num: 2 (153,20)
# ): ) (153,21)
# ^: ^ (153,23)
# num: 3 (153,25)
# ): ) (153,26)
# *: * (153,28)
# num: 4 (153,30)
# ): ) (153,31)
# /: / (153,33)
# num: 5 (153,35)
# ): ) (153,36)
# ;: ; (154,2)
# id: print (155,11)
# (: ( (155,12)
# str: "Hello World" (155,25)
# ): ) (155,26)
# ;: ; (156,2)
# id: print (157,11)
# (: ( (157,12)
# str: "The message is " (157,29)
# type_id: Hello (157,34)
# type_id: World (157,40)
# str: "" (157,42)
# ): ) (157,43)
# ;: ; (158,2)
# id: print (159,11)
# (: ( (159,12)
# str: "The meaning of life is " (159,37)
# @: @ (159,39)
# num: 42 (159,42)
# ): ) (159,43)
# ;: ; (160,2)
# id: print (161,11)
# (: ( (161,12)
# id: sin (161,15)
# (: ( (161,16)
# num: 2 (161,17)
# *: * (161,19)
# const: PI (161,22)
# ): ) (161,23)
# ^: ^ (161,25)
# num: 2 (161,27)
# +: + (161,29)
# id: cos (161,33)
# (: ( (161,34)
# num: 3 (161,35)
# *: * (161,37)
# const: PI (161,40)
# /: / (161,42)
# id: log (161,46)
# (: ( (161,47)
# num: 4 (161,48)
# ,: , (161,49)
# num: 64 (161,52)
# ): ) (161,53)
# ): ) (161,54)
# ): ) (161,55)
# ;: ; (162,2)
# {: { (164,2)
# id: print (165,15)
# (: ( (165,16)
# num: 42 (165,18)
# ): ) (165,19)
# ;: ; (166,2)
# id: print (167,15)
# (: ( (167,16)
# id: sin (167,19)
# (: ( (167,20)
# const: PI (167,22)
# /: / (167,23)
# num: 2 (167,24)
# ): ) (167,25)
# ): ) (167,26)
# ;: ; (168,2)
# id: print (169,15)
# (: ( (169,16)
# str: "Hello World" (169,29)
# ): ) (169,30)
# ;: ; (170,2)
# }: } (172,2)
# id: print (175,13)
# (: ( (175,14)
# id: tan (175,17)
# (: ( (175,18)
# const: PI (175,20)
# ): ) (175,21)
# *: * (175,23)
# num: 2 (175,25)
# +: + (175,27)
# id: cot (175,31)
# (: ( (175,32)
# const: PI (175,34)
# ): ) (175,35)
# *: * (175,37)
# num: 2 (175,39)
# ): ) (175,40)
# ;: ; (176,2)
# let: let (178,10)
# id: msg (178,14)
# =: = (178,16)
# str: "Hello World" (178,30)
# in: in (178,33)
# id: print (178,39)
# (: ( (178,40)
# id: msg (178,43)
# ): ) (178,44)
# ;: ; (179,2)
# let: let (180,9)
# id: number (180,16)
# =: = (180,18)
# num: 42 (180,21)
# ,: , (180,22)
# id: text (180,27)
# =: = (180,29)
# str: "The meaning of life is" (180,54)
# in: in (181,3)
# id: print (182,15)
# (: ( (182,16)
# id: text (182,20)
# @: @ (182,22)
# id: number (182,29)
# ): ) (182,30)
# ;: ; (183,2)
# let: let (184,9)
# id: number (184,16)
# =: = (184,18)
# num: 42 (184,21)
# in: in (185,3)
# let: let (186,13)
# id: text (186,18)
# =: = (186,20)
# str: "The meaning of life is" (186,45)
# in: in (187,3)
# id: print (188,19)
# (: ( (188,20)
# id: text (188,24)
# @: @ (188,26)
# id: number (188,33)
# ): ) (188,34)
# ;: ; (189,2)
# let: let (190,9)
# id: number (190,16)
# =: = (190,18)
# num: 42 (190,21)
# in: in (190,24)
# (: ( (191,2)
# let: let (192,13)
# id: text (192,18)
# =: = (192,20)
# str: "The meaning of life is" (192,45)
# in: in (192,48)
# (: ( (193,2)
# id: print (194,23)
# (: ( (194,24)
# id: text (194,28)
# @: @ (194,30)
# id: number (194,37)
# ): ) (195,2)
# ): ) (197,2)
# ): ) (198,11)
# ;: ; (199,2)
# let: let (200,9)
# id: a (200,11)
# =: = (200,13)
# num: 6 (200,15)
# ,: , (200,16)
# id: b (200,18)
# =: = (200,20)
# id: a (200,22)
# *: * (200,24)
# num: 7 (200,26)
# in: in (200,29)
# id: print (200,35)
# (: ( (200,36)
# id: b (200,37)
# ): ) (200,38)
# ;: ; (201,2)
# let: let (202,9)
# id: a (202,11)
# =: = (202,13)
# num: 6 (202,15)
# in: in (203,3)
# let: let (204,13)
# id: b (204,15)
# =: = (204,17)
# id: a (204,19)
# *: * (204,21)
# num: 7 (204,23)
# in: in (205,3)
# id: print (206,19)
# (: ( (206,20)
# id: b (206,21)
# ): ) (206,22)
# ;: ; (207,2)
# let: let (208,9)
# id: a (208,11)
# =: = (208,13)
# num: 5 (208,15)
# ,: , (208,16)
# id: b (208,18)
# =: = (208,20)
# num: 10 (208,23)
# ,: , (208,24)
# id: c (208,26)
# =: = (208,28)
# num: 20 (208,31)
# in: in (208,34)
# {: { (209,2)
# id: print (210,15)
# (: ( (210,16)
# id: a (210,17)
# +: + (210,18)
# id: b (210,19)
# ): ) (210,20)
# ;: ; (211,2)
# id: print (212,15)
# (: ( (212,16)
# id: b (212,17)
# *: * (212,18)
# id: c (212,19)
# ): ) (212,20)
# ;: ; (213,2)
# id: print (214,15)
# (: ( (214,16)
# id: c (214,17)
# /: / (214,18)
# id: a (214,19)
# ): ) (214,20)
# ;: ; (215,2)
# }: } (216,7)
# ;: ; (217,2)
# let: let (218,9)
# id: a (218,11)
# =: = (218,13)
# (: ( (218,15)
# let: let (218,18)
# id: b (218,20)
# =: = (218,22)
# num: 6 (218,24)
# in: in (218,27)
# id: b (218,29)
# *: * (218,31)
# num: 7 (218,33)
# ): ) (218,34)
# in: in (218,37)
# id: print (218,43)
# (: ( (218,44)
# id: a (218,45)
# ): ) (218,46)
# ;: ; (219,2)
# id: print (220,11)
# (: ( (220,12)
# let: let (220,15)
# id: b (220,17)
# =: = (220,19)
# num: 6 (220,21)
# in: in (220,24)
# id: b (220,26)
# *: * (220,28)
# num: 7 (220,30)
# ): ) (220,31)
# ;: ; (221,2)
# let: let (222,9)
# id: a (222,11)
# =: = (222,13)
# num: 20 (222,16)
# in: in (222,19)
# {: { (223,2)
# let: let (224,13)
# id: a (224,15)
# =: = (224,17)
# num: 42 (224,20)
# in: in (224,23)
# id: print (224,29)
# (: ( (224,30)
# id: a (224,31)
# ): ) (224,32)
# ;: ; (225,2)
# id: print (226,15)
# (: ( (226,16)
# id: a (226,17)
# ): ) (226,18)
# ;: ; (227,2)
# }: } (228,7)
# ;: ; (229,2)
# let: let (230,9)
# id: a (230,11)
# =: = (230,13)
# num: 7 (230,15)
# ,: , (230,16)
# id: a (230,18)
# =: = (230,20)
# num: 7 (230,22)
# *: * (230,24)
# num: 6 (230,26)
# in: in (230,29)
# id: print (230,35)
# (: ( (230,36)
# id: a (230,37)
# ): ) (230,38)
# ;: ; (231,2)
# let: let (232,9)
# id: a (232,11)
# =: = (232,13)
# num: 7 (232,15)
# in: in (233,3)
# let: let (234,13)
# id: a (234,15)
# =: = (234,17)
# num: 7 (234,19)
# *: * (234,21)
# num: 6 (234,23)
# in: in (235,3)
# id: print (236,19)
# (: ( (236,20)
# id: a (236,21)
# ): ) (236,22)
# ;: ; (237,2)
# let: let (238,9)
# id: a (238,11)
# =: = (238,13)
# num: 0 (238,15)
# in: in (238,18)
# {: { (239,2)
# id: print (240,15)
# (: ( (240,16)
# id: a (240,17)
# ): ) (240,18)
# ;: ; (241,2)
# id: a (242,11)
# :=: := (242,14)
# num: 1 (242,16)
# ;: ; (243,2)
# id: print (244,15)
# (: ( (244,16)
# id: a (244,17)
# ): ) (244,18)
# ;: ; (245,2)
# }: } (246,7)
# ;: ; (247,2)
# let: let (248,9)
# id: a (248,11)
# =: = (248,13)
# num: 0 (248,15)
# in: in (249,3)
# let: let (250,13)
# id: b (250,15)
# =: = (250,17)
# id: a (250,19)
# :=: := (250,22)
# num: 1 (250,24)
# in: in (250,27)
# {: { (251,2)
# id: print (252,19)
# (: ( (252,20)
# id: a (252,21)
# ): ) (252,22)
# ;: ; (253,2)
# id: print (254,19)
# (: ( (254,20)
# id: b (254,21)
# ): ) (254,22)
# ;: ; (255,2)
# }: } (256,11)
# ;: ; (257,2)
# let: let (258,9)
# id: a (258,11)
# =: = (258,13)
# num: 42 (258,16)
# in: in (258,19)
# if: if (258,22)
# (: ( (258,24)
# id: a (258,25)
# %: % (258,27)
# num: 2 (258,29)
# ==: == (258,32)
# num: 0 (258,34)
# ): ) (258,35)
# id: print (258,41)
# (: ( (258,42)
# str: "Even" (258,48)
# ): ) (258,49)
# else: else (258,54)
# id: print (258,60)
# (: ( (258,61)
# str: "odd" (258,66)
# ): ) (258,67)
# ;: ; (259,2)
# let: let (260,9)
# id: a (260,11)
# =: = (260,13)
# num: 42 (260,16)
# in: in (260,19)
# id: print (260,25)
# (: ( (260,26)
# if: if (260,28)
# (: ( (260,30)
# id: a (260,31)
# %: % (260,33)
# num: 2 (260,35)
# ==: == (260,38)
# num: 0 (260,40)
# ): ) (260,41)
# str: "even" (260,48)
# else: else (260,53)
# str: "odd" (260,59)
# ): ) (260,60)
# ;: ; (261,2)
# let: let (262,9)
# id: a (262,11)
# =: = (262,13)
# num: 42 (262,16)
# in: in (263,3)
# if: if (264,12)
# (: ( (264,14)
# id: a (264,15)
# %: % (264,17)
# num: 2 (264,19)
# ==: == (264,22)
# num: 0 (264,24)
# ): ) (264,25)
# {: { (265,2)
# id: print (266,19)
# (: ( (266,20)
# id: a (266,21)
# ): ) (266,22)
# ;: ; (267,2)
# id: print (268,19)
# (: ( (268,20)
# str: "Even" (268,26)
# ): ) (268,27)
# ;: ; (269,2)
# }: } (271,2)
# else: else (272,14)
# id: print (272,20)
# (: ( (272,21)
# str: "Odd" (272,26)
# ): ) (272,27)
# ;: ; (273,2)
# let: let (274,9)
# id: a (274,11)
# =: = (274,13)
# num: 42 (274,16)
# ,: , (274,17)
# let: let (274,21)
# id: mod (274,25)
# =: = (274,27)
# id: a (274,29)
# %: % (274,31)
# num: 3 (274,33)
# in: in (274,36)
# /: / (274,38)
# /: / (274,39)
# id: error (275,6)
# id: print (276,15)
# (: ( (277,2)
# if: if (278,16)
# (: ( (278,18)
# id: mod (278,21)
# ==: == (278,24)
# num: 0 (278,26)
# ): ) (278,27)
# str: "Magic" (279,8)
# elif: elif (280,18)
# (: ( (280,20)
# id: mod (280,23)
# %: % (280,25)
# num: 3 (280,27)
# ==: == (280,30)
# num: 1 (280,32)
# ): ) (280,33)
# str: "Woke" (281,7)
# else: else (282,18)
# str: "Dumb" (283,7)
# ): ) (284,11)
# ;: ; (285,2)
# let: let (286,9)
# id: a (286,11)
# =: = (286,13)
# num: 10 (286,16)
# in: in (286,19)
# while: while (286,25)
# (: ( (286,27)
# id: a (286,28)
# >=: >= (286,31)
# num: 0 (286,33)
# ): ) (286,34)
# {: { (287,2)
# id: print (288,15)
# (: ( (288,16)
# id: a (288,17)
# ): ) (288,18)
# ;: ; (289,2)
# id: a (290,11)
# :=: := (290,14)
# id: a (290,16)
# -: - (290,18)
# num: 1 (290,20)
# ;: ; (291,2)
# }: } (293,2)
# for: for (295,10)
# (: ( (295,12)
# id: x (295,13)
# in: in (295,16)
# id: range (295,22)
# (: ( (295,23)
# num: 0 (295,24)
# ,: , (295,25)
# num: 10 (295,28)
# ): ) (295,29)
# ): ) (295,30)
# id: print (295,36)
# (: ( (295,37)
# id: x (295,38)
# ): ) (295,39)
# ;: ; (296,2)
# let: let (297,9)
# id: iterable (297,18)
# =: = (297,20)
# id: range (297,26)
# (: ( (297,27)
# num: 0 (297,28)
# ,: , (297,29)
# num: 10 (297,32)
# ): ) (297,33)
# in: in (298,3)
# while: while (299,15)
# (: ( (299,17)
# id: iterable (299,25)
# .: . (299,26)
# id: next (299,30)
# (: ( (299,31)
# ): ) (299,32)
# ): ) (300,2)
# let: let (301,17)
# id: x (301,19)
# =: = (301,21)
# id: iterable (301,30)
# .: . (301,31)
# id: current (301,38)
# (: ( (301,39)
# ): ) (301,40)
# in: in (302,3)
# id: print (303,23)
# (: ( (303,24)
# id: x (303,25)
# ): ) (303,26)
# ;: ; (304,2)
# let: let (306,10)
# id: pt (306,13)
# =: = (306,15)
# new: new (306,19)
# type_id: Point (306,25)
# (: ( (306,26)
# ): ) (306,27)
# in: in (306,30)
# /: / (306,32)
# /: / (306,33)
# id: error (307,6)
# id: print (308,15)
# (: ( (308,16)
# str: "x: " (308,21)
# @: @ (308,23)
# id: pt (308,26)
# .: . (308,27)
# id: getX (308,31)
# (: ( (308,32)
# ): ) (308,33)
# @: @ (308,35)
# str: "; y: " (308,43)
# @: @ (308,45)
# id: pt (308,48)
# .: . (308,49)
# id: getY (308,53)
# (: ( (308,54)
# ): ) (308,55)
# ): ) (308,56)
# ;: ; (309,2)
# let: let (310,9)
# id: pt (310,12)
# =: = (310,14)
# new: new (310,18)
# type_id: Point (310,24)
# (: ( (310,25)
# num: 3 (310,26)
# ,: , (310,27)
# num: 4 (310,28)
# ): ) (310,29)
# in: in (311,3)
# id: print (312,15)
# (: ( (312,16)
# str: "x: " (312,21)
# @: @ (312,23)
# id: pt (312,26)
# .: . (312,27)
# id: getX (312,31)
# (: ( (312,32)
# ): ) (312,33)
# @: @ (312,35)
# str: "; y: " (312,43)
# @: @ (312,45)
# id: pt (312,48)
# .: . (312,49)
# id: getY (312,53)
# (: ( (312,54)
# ): ) (312,55)
# ): ) (312,56)
# ;: ; (313,2)
# let: let (314,9)
# id: pt (314,12)
# =: = (314,14)
# new: new (314,18)
# type_id: PolarPoint (314,29)
# (: ( (314,30)
# num: 3 (314,31)
# ,: , (314,32)
# num: 4 (314,33)
# ): ) (314,34)
# in: in (315,3)
# id: print (316,15)
# (: ( (316,16)
# str: "rho: " (316,23)
# @: @ (316,25)
# id: pt (316,28)
# .: . (316,29)
# id: rho (316,32)
# (: ( (316,33)
# ): ) (316,34)
# ): ) (316,35)
# ;: ; (317,2)
# let: let (319,10)
# id: p (319,12)
# =: = (319,14)
# new: new (319,18)
# type_id: Knight (319,25)
# (: ( (319,26)
# str: "Phil" (319,32)
# ,: , (319,33)
# str: "Collins" (319,43)
# ): ) (319,44)
# in: in (320,3)
# id: print (321,15)
# (: ( (321,16)
# id: p (321,17)
# .: . (321,18)
# id: name (321,22)
# (: ( (321,23)
# ): ) (321,24)
# ): ) (321,25)
# ;: ; (322,2)
# let: let (323,9)
# id: p (323,11)
# :: : (323,12)
# type_id: Person (323,19)
# =: = (323,21)
# new: new (323,25)
# type_id: Knight (323,32)
# (: ( (323,33)
# str: "Phil" (323,39)
# ,: , (323,40)
# str: "Collins" (323,50)
# ): ) (323,51)
# in: in (323,54)
# id: print (323,60)
# (: ( (323,61)
# id: p (323,62)
# .: . (323,63)
# id: name (323,67)
# (: ( (323,68)
# ): ) (323,69)
# ): ) (323,70)
# ;: ; (324,2)
# let: let (325,9)
# id: x (325,11)
# :: : (325,12)
# type_id: Number (325,19)
# =: = (325,21)
# num: 42 (325,24)
# in: in (325,27)
# id: print (325,33)
# (: ( (325,34)
# id: x (325,35)
# ): ) (325,36)
# ;: ; (326,2)
# let: let (328,10)
# id: x (328,12)
# =: = (328,14)
# new: new (328,18)
# type_id: Superman (328,27)
# (: ( (328,28)
# ): ) (328,29)
# in: in (329,3)
# id: print (330,15)
# (: ( (331,2)
# if: if (332,16)
# (: ( (332,18)
# id: x (332,19)
# is: is (332,22)
# type_id: Bird (332,27)
# ): ) (332,28)
# str: "It's bird!" (333,13)
# elif: elif (334,18)
# (: ( (334,20)
# id: x (334,21)
# is: is (334,24)
# type_id: Plane (334,30)
# ): ) (334,31)
# str: "It's a plane!" (335,16)
# else: else (336,18)
# str: "No, it's Superman!" (337,21)
# ): ) (338,11)
# ;: ; (339,2)
# let: let (340,9)
# id: x (340,11)
# =: = (340,13)
# num: 42 (340,16)
# in: in (340,19)
# id: print (340,25)
# (: ( (340,26)
# id: x (340,27)
# ): ) (340,28)
# ;: ; (341,2)
# let: let (342,9)
# id: total (342,15)
# =: = (342,17)
# {: { (342,19)
# id: print (342,25)
# (: ( (342,26)
# str: "Total" (342,33)
# ): ) (342,34)
# ;: ; (342,35)
# num: 5 (342,37)
# ;: ; (342,38)
# }: } (342,40)
# +: + (342,42)
# num: 6 (342,44)
# in: in (342,47)
# id: print (342,53)
# (: ( (342,54)
# id: total (342,59)
# ): ) (342,60)
# ;: ; (343,2)
# let: let (344,9)
# id: x (344,11)
# :: : (344,13)
# type_id: A (344,15)
# =: = (344,17)
# if: if (344,20)
# (: ( (344,22)
# id: rand (344,26)
# (: ( (344,27)
# ): ) (344,28)
# <: < (344,30)
# num: 0.5 (344,34)
# ): ) (344,35)
# new: new (344,39)
# type_id: B (344,41)
# (: ( (344,42)
# ): ) (344,43)
# else: else (344,48)
# new: new (344,52)
# type_id: C (344,54)
# (: ( (344,55)
# ): ) (344,56)
# in: in (345,3)
# if: if (346,12)
# (: ( (346,14)
# id: x (346,15)
# is: is (346,18)
# type_id: B (346,20)
# ): ) (347,2)
# let: let (348,17)
# id: y (348,19)
# :: : (348,21)
# type_id: B (348,23)
# =: = (348,25)
# id: x (348,27)
# as: as (348,30)
# type_id: B (348,32)
# in: in (348,35)
# {: { (349,2)
# id: y (350,19)
# .: . (350,20)
# id: hello (350,25)
# (: ( (350,26)
# ): ) (350,27)
# ;: ; (351,2)
# }: } (353,2)
# else: else (354,14)
# {: { (355,2)
# id: print (356,19)
# (: ( (356,20)
# str: "x cannot be downcasted to B" (356,49)
# ): ) (356,50)
# ;: ; (357,2)
# }: } (358,11)
# ;: ; (359,2)
# let: let (361,10)
# id: numbers (361,18)
# =: = (361,20)
# [: [ (361,22)
# num: 1 (361,23)
# ,: , (361,24)
# num: 2 (361,25)
# ,: , (361,26)
# num: 3 (361,27)
# ,: , (361,28)
# num: 4 (361,29)
# ,: , (361,30)
# num: 5 (361,31)
# ,: , (361,32)
# num: 6 (361,33)
# ,: , (361,34)
# num: 7 (361,35)
# ,: , (361,36)
# num: 8 (361,37)
# ,: , (361,38)
# num: 9 (361,39)
# ]: ] (361,40)
# in: in (362,3)
# for: for (363,13)
# (: ( (363,15)
# id: x (363,16)
# in: in (363,19)
# id: numbers (363,27)
# ): ) (364,2)
# id: print (365,19)
# (: ( (365,20)
# id: x (365,21)
# ): ) (365,22)
# ;: ; (366,2)
# let: let (367,9)
# id: numbers (367,17)
# =: = (367,19)
# [: [ (367,21)
# num: 1 (367,22)
# ,: , (367,23)
# num: 2 (367,24)
# ,: , (367,25)
# num: 3 (367,26)
# ,: , (367,27)
# num: 4 (367,28)
# ,: , (367,29)
# num: 5 (367,30)
# ,: , (367,31)
# num: 6 (367,32)
# ,: , (367,33)
# num: 7 (367,34)
# ,: , (367,35)
# num: 8 (367,36)
# ,: , (367,37)
# num: 9 (367,38)
# ]: ] (367,39)
# in: in (367,42)
# id: print (367,48)
# (: ( (367,49)
# id: numbers (367,56)
# [: [ (367,57)
# num: 7 (367,58)
# ]: ] (367,59)
# ): ) (367,60)
# ;: ; (368,2)
# let: let (369,9)
# id: squares (369,17)
# =: = (369,19)
# [: [ (369,21)
# id: x (369,22)
# ^: ^ (369,23)
# num: 2 (369,24)
# ||: || (369,27)
# id: x (369,29)
# in: in (369,32)
# id: range (369,38)
# (: ( (369,39)
# num: 1 (369,40)
# ,: , (369,41)
# num: 10 (369,43)
# ): ) (369,44)
# ]: ] (369,45)
# in: in (369,48)
# id: print (369,54)
# (: ( (369,55)
# id: x (369,56)
# ): ) (369,57)
# ;: ; (369,58)
# /: / (369,60)
# /: / (369,61)
# id: error (370,6)
# let: let (371,9)
# id: squares (371,17)
# =: = (371,19)
# [: [ (371,21)
# id: x (371,22)
# ^: ^ (371,23)
# num: 2 (371,24)
# ||: || (371,27)
# id: x (371,29)
# in: in (371,32)
# id: range (371,38)
# (: ( (371,39)
# num: 1 (371,40)
# ,: , (371,41)
# num: 10 (371,43)
# ): ) (371,44)
# ]: ] (371,45)
# in: in (371,48)
# for: for (371,52)
# (: ( (371,54)
# id: x (371,55)
# in: in (371,58)
# id: squares (371,66)
# ): ) (371,67)
# id: print (371,73)
# (: ( (371,74)
# id: x (371,75)
# ): ) (371,76)
# ;: ; (372,2)
# let: let (373,9)
# id: x (373,11)
# :: : (373,13)
# type_id: Hashable (373,22)
# =: = (373,24)
# new: new (373,28)
# type_id: Person (373,35)
# (: ( (373,36)
# ): ) (373,37)
# in: in (373,40)
# id: print (373,46)
# (: ( (373,47)
# id: x (373,48)
# .: . (373,49)
# id: hash (373,53)
# (: ( (373,54)
# ): ) (373,55)
# ): ) (373,56)
# ;: ; (374,2)
# let: let (375,9)
# id: x (375,11)
# :: : (375,13)
# type_id: Hashable (375,22)
# =: = (375,24)
# new: new (375,28)
# type_id: Point (375,34)
# (: ( (375,35)
# num: 0 (375,36)
# ,: , (375,37)
# num: 0 (375,38)
# ): ) (375,39)
# in: in (375,42)
# id: print (375,48)
# (: ( (375,49)
# id: x (375,50)
# .: . (375,51)
# id: hash (375,55)
# (: ( (375,56)
# ): ) (375,57)
# ): ) (375,58)
# ;: ; (375,59)
# /: / (375,61)
# /: / (375,62)
# id: error (376,6)
# }: } (377,3)
# eof: $ (377,4)
